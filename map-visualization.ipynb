# %% [markdown]
# # Base Maps

# %% [markdown]
# ## Shapefiles
# **PhilGIS** [https://www.philgis.org]
#
# Libraries:
# * GeoPandas []

# %%
# %matplotlib inline
import geopandas as gpd
pgismnl_flat = gpd.read_file('shp/metro-manila.shp')

# %%
pgismnl_flat.columns
# Out:
# Index(['ID_0', 'ISO', 'NAME_0', 'ID_1', 'NAME_1', 'ID_2', 'NAME_2', 'ID_3',
#        'NAME_3', 'NL_NAME_3', 'VARNAME_3', 'TYPE_3', 'ENGTYPE_3', 'PROVINCE',
#        'REGION', 'geometry'],
#       dtype='object')

# %%
pgismnl_flat.plot()

# %%
import rasterio as rio
import rasterio.plot as rioplot

# %%
pgismnl_dem = rio.open('tif/metro-manila.tif')

# %%
pgismnl_dem.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'int16',
#  'nodata': 32767.0,
#  'width': 775,
#  'height': 1557,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(0.00027777777777778797, 0.0, 120.91680555555578,
#         0.0, -0.00027777777777777843, 14.781527777777878)}

# %%
rioplot.show(pgismnl_dem, cmap="Blues")

# %% [markdown]
# ## ArcGIS API

# %% [markdown]
# To install package:

# %%
# !conda install -c esri arcgis
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# The command will also automatically install the dependencies ```arcpy``` has.

# %%
from arcgis.gis import GIS
gis = GIS("https://www.arcgis.com", "spddilidili", "pacifier15")

# %%
type(gis.content)
# Out:
# arcgis.gis.ContentManager

# %%
# search and list all feature layers in my contents
search_result = gis.content.search(query="", item_type="Feature Layer")
search_result
# Out:
# []

# %%
# search for content that begin with a prefix - say 'USA'
search_result_USA = gis.content.search(query="title:USA*")
search_result_USA
# Out:
# []

# %%
from IPython.display import display
for item in search_result_USA:
    display(item)

# %% [markdown]
# ## OpenStreetMap API

# %% [markdown]
# To install package:

# %%
# !pip install osmapi

# %% [markdown]
# Use this to extract data from OSM:

# %%
# !git clone https://github.com/interline-io/planetutils.git
# !python ./setup.py test
# !pip install .

# %% [markdown]
# 1. Sign up on: [https://www.interline.io/osm/extracts/]
# 2. Wait for confirmation email for your API token
#     * Don: __9d84929b-97df-4624-b115-e2db154ed385__

# %%
df = gpd.read_file('geojson/manila_philippines.geojson')

# %%
df.columns()
